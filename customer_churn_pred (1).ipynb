# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("churn.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
sns.set_style(style="whitegrid")

# %%
plt.figure(figsize=(12,10))

# %%
sns.countplot(x="Exited",data=df)
plt.title("exited")
# Out:
# Text(0.5, 1.0, 'exited')

# %%
sns.histplot(data=df, x="Age", kde=True)
plt.title("age distribution")
# Out:
# Text(0.5, 1.0, 'age distribution')

# %%
sns.scatterplot(data=df, x="CreditScore", y="Age", hue="Exited")
plt.title("Credit Score VS Age")
# Out:
# Text(0.5, 1.0, 'Credit Score VS Age')

# %%
sns.boxplot(x="Exited",y="Balance",data=df)
plt.title("Balance distribution by Churn")
# Out:
# Text(0.5, 1.0, 'Balance distribution by Churn')

# %%
sns.boxplot(x="Exited",y="CreditScore",data=df)
plt.title("Credit distribution by Churn")
# Out:
# Text(0.5, 1.0, 'Credit distribution by Churn')

# %%
analysis_table = df
analysis_table = analysis_table.drop(["RowNumber","CustomerId","Surname"], axis=1)

# %%
analysis_table
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
sns.scatterplot(data=analysis_table, x="CreditScore", y="Age", hue="Exited")
plt.title("Credit Score VS Age")
# Out:
# Text(0.5, 1.0, 'Credit Score VS Age')

# %%
print(analysis_table["Gender"].value_counts())
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
analysis_table[analysis_table['Exited'] == 1]['Gender'].value_counts()
# Out:
# Gender
# Female    1139
# Male       898
# Name: count, dtype: int64

# %%
gender_distribution = analysis_table['Gender'].value_counts()
churn_by_gender = analysis_table[analysis_table['Exited'] == 1]['Gender'].value_counts()

# %%
summary = pd.DataFrame({
    "Total Customers": gender_distribution,
    "Churned Customers": churn_by_gender
}).fillna(0)

# %%
print("\nSummary Table:\n", summary)
# Out:
# Summary Table:
#          Total Customers  Churned Customers
# Gender
# Female             4543               1139
# Male               5457                898

# %%
analysis_table[(analysis_table['Age']>70) & (analysis_table['Exited']==1)]
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 1410          523    France  Female   73       7       0.00              2
# 2553          727     Spain    Male   71       8       0.00              1
# 3110          546   Germany  Female   74       8  114888.74              2
# 3317          779    France    Male   71       3       0.00              2
# 3531          408    France  Female   84       8   87873.39              1
# 5664          667     Spain    Male   71       4  137260.78              1
# 6581          576   Germany  Female   71       6  140273.47              1
# 7058          624    France  Female   71       4  170252.05              3
# 7499          609   Germany  Female   71       6  113317.10              1
# 9555          782   Germany  Female   72       5  148666.99              1
# 9646          850     Spain    Male   71      10   69608.14              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
analysis_table[(analysis_table['Age']>70)]
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 85            652     Spain  Female   75      10       0.00              2
# 158           646    France  Female   73       6   97259.25              1
# 230           673    France    Male   72       1       0.00              2
# 252           681    France  Female   79       0       0.00              2
# 310           652    France  Female   80       4       0.00              2
# ...           ...       ...     ...  ...     ...        ...            ...
# 9646          850     Spain    Male   71      10   69608.14              1
# 9671          649   Germany    Male   78       4   68345.86              2
# 9736          659     Spain    Male   78       2  151675.65              1
# 9894          521    France  Female   77       6       0.00              2
# 9936          609    France    Male   77       1       0.00              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
filtered_data = analysis_table[(analysis_table['Age'] > 35) & (analysis_table['Age'] < 70)]

# %%
filtered_data
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9991          597    France  Female   53       4   88381.21              1
# 9992          726     Spain    Male   36       2       0.00              1
# 9995          771    France    Male   39       5       0.00              2
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
sns.scatterplot(data=filtered_data, x="CreditScore", y="Age", hue="Exited")
plt.title("Credit Score VS Age")
# Out:
# Text(0.5, 1.0, 'Credit Score VS Age')

# %%
sns.countplot(x="Exited",data=filtered_data)
plt.title("exited")
# Out:
# Text(0.5, 1.0, 'exited')

# %%
#filtered_data[(filtered_data["CreditScore"] < 450) & (filtered_data["Exited"] == 1)]
filtered_data[(filtered_data["CreditScore"] < 400)]
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 942           376   46       6       0.00              1          1
# 1201          399   46       2  127655.22              1          1
# 1405          359   44       6  128747.69              1          1
# 1631          350   54       1  152677.48              1          1
# 1838          350   39       0  109733.20              2          0
# 1962          358   52       8  143542.36              3          1
# 2473          351   57       4  163146.46              1          1
# 5285          386   53       1  131955.07              1          1
# 5494          383   48       8   95808.19              1          0
# 8154          367   42       6   93608.28              1          1
# 8723          350   51      10       0.00              1          1
# 8762          350   60       3       0.00              1          0
# 9210          382   36       0       0.00              1          1
# ...

# %%
filtered_data[(filtered_data["CreditScore"] > 800) & (filtered_data["Exited"]==0)]
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 4             850     Spain  Female   43       2  125510.82              1
# 6             822    France    Male   50       7       0.00              2
# 24            846    France  Female   38       5       0.00              1
# 38            850    France    Male   36       7       0.00              1
# 91            808    France    Male   45       7  118626.55              2
# ...           ...       ...     ...  ...     ...        ...            ...
# 9761          807   Germany  Female   60       1   72948.58              2
# 9780          816   Germany  Female   40       9  109003.26              1
# 9822          808   Germany    Male   39       3  124216.93              1
# 9926          803    France    Male   36       1       0.00              2
# 9949          850    France  Female   47       9  137301.87              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
filtered_data[(filtered_data["CreditScore"] > 800) & (filtered_data["Exited"]==1) ]
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 43            834    France  Female   49       2  131394.56              1
# 184           804    France  Female   50       4       0.00              1
# 218           807    France    Male   43       1  105799.32              2
# 338           805     Spain  Female   39       5  165272.13              1
# 467           816   Germany  Female   38       5  130878.75              3
# ...           ...       ...     ...  ...     ...        ...            ...
# 9255          847   Germany  Female   41       3  101543.51              4
# 9527          850    France  Female   40       9   99816.46              1
# 9577          841   Germany  Female   52       3  112383.03              1
# 9716          812   Germany    Male   39       5  115730.71              3
# 9809          820    France  Female   39       1  104614.29              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
filtered_data[(filtered_data["CreditScore"] > 800) & (filtered_data["Exited"]==1) & (filtered_data["Gender"]=="Female")]
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 43            834    France  Female   49       2  131394.56              1
# 184           804    France  Female   50       4       0.00              1
# 338           805     Spain  Female   39       5  165272.13              1
# 467           816   Germany  Female   38       5  130878.75              3
# 644           819    France  Female   39       9  133102.92              1
# 1018          850   Germany  Female   45       5  103909.86              1
# 1046          807     Spain  Female   42       1       0.00              1
# 1306          823     Spain  Female   46       3   81576.75              1
# 1381          846    France  Female   41       5       0.00              3
# 1459          817    France  Female   55      10  117561.49              1
# 1469          819   Germany  Female   49       1  120656.86              4
# ...

# %%
filtered_data = pd.get_dummies(filtered_data, columns=["Gender","Geography"])

# %%
filtered_data['CreditScore']<400
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9991    False
# 9992    False
# 9995    False
# 9997    False
# 9998    False
# Name: CreditScore, Length: 5696, dtype: bool

# %% [markdown]
# # Filtered data now only contains row with **CreditScore** > 400

# %%
filtered_data = filtered_data[(filtered_data['CreditScore'] > 400)]

# %%
filtered_data = filtered_data.dropna()

# %%
features = filtered_data.drop(['Exited'],axis=1)

# %%
target = filtered_data["Exited"]

# %%
filtered_data[filtered_data['CreditScore']<400]
# Out:
# Empty DataFrame
# Columns: [CreditScore, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited, Gender_Female, Gender_Male, Geography_France, Geography_Germany, Geography_Spain]
# Index: []

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9991          597   53       4   88381.21              1          1
# 9992          726   36       2       0.00              1          1
# 9995          771   39       5       0.00              2          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
#
#       IsActiveMember  EstimatedSalary  Gender_Female  Gender_Male  \
# 0                  1        101348.88           True        False
# ...

# %%
# !pip install catboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **Now splitting the data into training and testing set **

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pickle
import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# x_train: Features for training.
#
# y_train: Labels for training.
#
# x_test: Features for testing.
#
# y_test: Labels for testing.

# %%
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42, stratify=target)
x_train
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 4611          555   48       3  142055.41              2          0
# 1904          625   69       1  107569.96              1          1
# 9135          727   49       7   96296.78              1          1
# 558           741   53       3       0.00              2          1
# 1276          635   37       5  113488.68              1          1
# ...           ...  ...     ...        ...            ...        ...
# 5830          684   37       4  138476.41              2          1
# 7827          605   41      10       0.00              2          0
# 2932          688   54       9       0.00              1          1
# 8665          821   40       1       0.00              2          1
# 6021          714   52       4  100755.66              1          1
#
#       IsActiveMember  EstimatedSalary  Gender_Female  Gender_Male  \
# 4611               1         79134.78          False         True
# ...

# %% [markdown]
# we have to transform the data and scale out so that all values are on an even scale. Here the balance and credit column has too high values that can effect the training.

# %%
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
x_train[0]
# Out:
# array([-1.01771593,  0.44229441, -0.68691031,  1.0379938 ,  0.78418291,
#        -1.50790425,  0.98384526, -0.3721501 , -0.93147899,  0.93147899,
#        -0.97393122,  1.66367891, -0.57396203])

# %% [markdown]
# Now we're going to use multiple models and see the difference in how they perform.
#
# Our actual problem is Binary-Classification to see if the customer has churned or not!

# %% [markdown]
# 1- Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
lr_model = LogisticRegression(random_state = 42) #random state ensures the reproducibility

# %%
lr_model.fit(x_train, y_train) #model is trained on train-data
# Out:
# LogisticRegression(random_state=42)

# %%
lr_predictions = lr_model.predict(x_test)

# %%
lr_predictions
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
lr_accuracy = accuracy_score(y_test, lr_predictions)

# %%
lr_accuracy
# Out:
# 0.7458223394898856

# %%
def evaluate_and_save_model(model,x_train,x_test,y_train,y_test,filename):
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"{model.__class__.__name__} , Accuracy : {accuracy:4f}")
    print(f"\n Classification report :\n {classification_report(y_test,y_pred,target_names=['Not churned', 'Churned'])}")
    print("-----------------------------------------------------------")

    with open(filename, "wb") as file:
        pickle.dump(model,file)

    print(f"Model saved as {filename}")

# %%
xgb_model = xgb.XGBClassifier(random_state=42)
evaluate_and_save_model(xgb_model,x_train,x_test,y_train,y_test,"xgb_model.pkl")

dt_model = DecisionTreeClassifier(random_state=42)
evaluate_and_save_model(dt_model,x_train,x_test,y_train,y_test,"dt_model.pkl")

rf_model = RandomForestClassifier(random_state=42)
evaluate_and_save_model(rf_model,x_train,x_test,y_train,y_test,"rf_model.pkl")

nb_model = GaussianNB()
evaluate_and_save_model(nb_model,x_train,x_test,y_train,y_test,"nb_model.pkl")

knn_model = KNeighborsClassifier()
evaluate_and_save_model(knn_model,x_train,x_test,y_train,y_test,"knn_model.pkl")

svm_model = SVC(random_state=42)
evaluate_and_save_model(svm_model,x_train,x_test,y_train,y_test,"svm_model.pkl")


lgbm_model = lgb.LGBMClassifier(random_state=42)
evaluate_and_save_model(lgbm_model,x_train,x_test,y_train,y_test,"lgbm_model.pkl")

catboost_model = CatBoostClassifier(random_state=42, verbose=0)
evaluate_and_save_model(catboost_model,x_train,x_test,y_train,y_test,"catboost_model.pkl")
# Out:
# XGBClassifier , Accuracy : 0.642920
#
#  Classification report :
#                precision    recall  f1-score   support
#
#  Not churned       0.78      0.69      0.73       805
#      Churned       0.41      0.52      0.46       332
#
#     accuracy                           0.64      1137
#    macro avg       0.60      0.61      0.60      1137
# weighted avg       0.67      0.64      0.65      1137
#
# -----------------------------------------------------------
# Model saved as xgb_model.pkl
# DecisionTreeClassifier , Accuracy : 0.729112
#
#  Classification report :
#                precision    recall  f1-score   support
#
#  Not churned       0.83      0.78      0.80       805
#      Churned       0.53      0.60      0.56       332
#
#     accuracy                           0.73      1137
#    macro avg       0.68      0.69      0.68      1137
# weighted avg       0.74      0.73      0.73      1137
#
# -----------------------------------------------------------
# ...

# %% [markdown]
# # Feature Engineering can be done but in this case, it woresened the output so dropped it.

# %%
#feature_importances = xgb_model.feature_importances_

feature_importances = dt_model.feature_importances_
feature_names = features.columns

# %%
features.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Gender_Female  Gender_Male  \
# 0               1        101348.88           True        False
# 1               1        112542.58           True        False
# 2               0        113931.57           True        False
# 3               0         93826.63           True        False
# 4               1         79084.10           True        False
#
#    Geography_France  Geography_Germany  Geography_Spain
# 0              True              False            False
# 1             False              False             True
# ...

# %%
feature_names
# Out:
# Index(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Gender_Female', 'Gender_Male',
#        'Geography_France', 'Geography_Germany', 'Geography_Spain'],
#       dtype='object')

# %%
feature_importances
# Out:
# array([0.14333379, 0.18909556, 0.07984835, 0.14595689, 0.12461938,
#        0.01905909, 0.07361385, 0.15333314, 0.0120243 , 0.01318208,
#        0.00999834, 0.02808114, 0.00785409])

# %%
print(len(feature_names), len(feature_importances))
# Out:
# 13 13

# %%
feature_importances_df = pd.DataFrame({
    'feature':feature_names,
    'importance':feature_importances
})

# %%
feature_importances_df
# Out:
#               feature  importance
# 0         CreditScore    0.143334
# 1                 Age    0.189096
# 2              Tenure    0.079848
# 3             Balance    0.145957
# 4       NumOfProducts    0.124619
# 5           HasCrCard    0.019059
# 6      IsActiveMember    0.073614
# 7     EstimatedSalary    0.153333
# 8       Gender_Female    0.012024
# 9         Gender_Male    0.013182
# 10   Geography_France    0.009998
# 11  Geography_Germany    0.028081
# 12    Geography_Spain    0.007854

# %%
feature_importances_df = feature_importances_df.sort_values("importance", ascending=False)

# %%
feature_importances_df
# Out:
#               feature  importance
# 1                 Age    0.189096
# 7     EstimatedSalary    0.153333
# 3             Balance    0.145957
# 0         CreditScore    0.143334
# 4       NumOfProducts    0.124619
# 2              Tenure    0.079848
# 6      IsActiveMember    0.073614
# 11  Geography_Germany    0.028081
# 5           HasCrCard    0.019059
# 9         Gender_Male    0.013182
# 8       Gender_Female    0.012024
# 10   Geography_France    0.009998
# 12    Geography_Spain    0.007854

# %%
plt.figure(figsize=(10,6))
plt.bar(feature_importances_df["feature"],feature_importances_df["importance"])
plt.xticks(rotation=90)
plt.xlabel("Features")
plt.ylabel("Importance")
plt.tight_layout()
plt.show()

# %%
#features['CLV'] = df['Balance'] * df['EstimatedSalary'] / 100000

# %%
sns.histplot(data=features, x="Age", kde=True)
plt.title("age distribution")
# Out:
# Text(0.5, 1.0, 'age distribution')

# %% [markdown]
# **High is for 35-45 (the max numebr of people)
# middle is the place of steep decline 45-50
# middle-low and low are almost linear 50-60, 60-70**

# %%
#features['tenure']=df['Tenure'] / df['Age']

# %% [markdown]
# # **SMOTE**

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9991          597   53       4   88381.21              1          1
# 9992          726   36       2       0.00              1          1
# 9995          771   39       5       0.00              2          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
#
#       IsActiveMember  EstimatedSalary  Gender_Female  Gender_Male  \
# 0                  1        101348.88           True        False
# ...

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(random_state=42)

# %%
x_resampled, y_resampled = smote.fit_resample(x_train,y_train)

# %%
#evaluate_and_save_model(xgb_model,x_resampled,x_test,y_resampled,y_test,"xgboost-smote.pkl")

xgb_model = xgb.XGBClassifier(random_state=42)
evaluate_and_save_model(xgb_model,x_resampled,x_test,y_resampled,y_test,"xgb_model_SMOTE.pkl")

dt_model = DecisionTreeClassifier(random_state=42)
evaluate_and_save_model(dt_model,x_resampled,x_test,y_resampled,y_test,"dt_model_SMOTE.pkl")

rf_model = RandomForestClassifier(random_state=42)
evaluate_and_save_model(rf_model,x_resampled,x_test,y_resampled,y_test,"rf_model_SMOTE.pkl")

nb_model = GaussianNB()
evaluate_and_save_model(nb_model,x_resampled,x_test,y_resampled,y_test,"nb_model_SMOTE.pkl")

knn_model = KNeighborsClassifier()
evaluate_and_save_model(knn_model,x_resampled,x_test,y_resampled,y_test,"knn_model_SMOTE.pkl")

svm_model = SVC(random_state=42)
evaluate_and_save_model(svm_model,x_resampled,x_test,y_resampled,y_test,"svm_model_SMOTE.pkl")


lgbm_model = lgb.LGBMClassifier(random_state=42)
evaluate_and_save_model(lgbm_model,x_resampled,x_test,y_resampled,y_test,"lgbm_model_SMOTE.pkl")

catboost_model = CatBoostClassifier(random_state=42, verbose=0)
evaluate_and_save_model(catboost_model,x_resampled,x_test,y_resampled,y_test,"catboost_model_SMOTE.pkl")
# Out:
# XGBClassifier , Accuracy : 0.321020
#
#  Classification report :
#                precision    recall  f1-score   support
#
#  Not churned       0.81      0.05      0.10       805
#      Churned       0.30      0.97      0.45       332
#
#     accuracy                           0.32      1137
#    macro avg       0.55      0.51      0.28      1137
# weighted avg       0.66      0.32      0.20      1137
#
# -----------------------------------------------------------
# Model saved as xgb_model_SMOTE.pkl
# DecisionTreeClassifier , Accuracy : 0.368514
#
#  Classification report :
#                precision    recall  f1-score   support
#
#  Not churned       0.78      0.15      0.25       805
#      Churned       0.30      0.90      0.45       332
#
#     accuracy                           0.37      1137
#    macro avg       0.54      0.52      0.35      1137
# weighted avg       0.64      0.37      0.31      1137
#
# -----------------------------------------------------------
# ...

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9991          597   53       4   88381.21              1          1
# 9992          726   36       2       0.00              1          1
# 9995          771   39       5       0.00              2          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
#
#       IsActiveMember  EstimatedSalary  Gender_Female  Gender_Male  \
# 0                  1        101348.88           True        False
# ...

# %% [markdown]
# **ENSEMBLING**

# %%
from sklearn.ensemble import VotingClassifier

# %%
voting_clf = VotingClassifier(
    estimators=[('xgboost', xgb.XGBClassifier(random_state=42)),('dt', DecisionTreeClassifier(random_state=42)),('lgbm', lgb.LGBMClassifier(random_state=42))],
    voting='soft'
)

# %%
evaluate_and_save_model(voting_clf,x_resampled,x_test,y_resampled,y_test,"voting_clf_soft.pkl")
# Out:
# [LightGBM] [Info] Number of positive: 3216, number of negative: 3216
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000618 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1446
# [LightGBM] [Info] Number of data points in the train set: 6432, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# VotingClassifier , Accuracy : 0.293755
#
#  Classification report :
#                precision    recall  f1-score   support
#
#  Not churned       0.58      0.01      0.02       805
#      Churned       0.29      0.98      0.45       332
#
#     accuracy                           0.29      1137
#    macro avg       0.44      0.50      0.23      1137
# weighted avg       0.50      0.29      0.14      1137
#
# -----------------------------------------------------------
# ...

# %%
voting_clf = VotingClassifier(
    estimators=[('xgboost', xgb.XGBClassifier(random_state=42)),('dt', DecisionTreeClassifier(random_state=42)),('lgbm', lgb.LGBMClassifier(random_state=42))],
    voting='hard'
)

# %%
evaluate_and_save_model(voting_clf,x_resampled,x_test,y_resampled,y_test,"voting_clf_hard.pkl")
# Out:
# [LightGBM] [Info] Number of positive: 3216, number of negative: 3216
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000509 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1446
# [LightGBM] [Info] Number of data points in the train set: 6432, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# VotingClassifier , Accuracy : 0.293755
#
#  Classification report :
#                precision    recall  f1-score   support
#
#  Not churned       0.60      0.01      0.01       805
#      Churned       0.29      0.99      0.45       332
#
#     accuracy                           0.29      1137
#    macro avg       0.45      0.50      0.23      1137
# weighted avg       0.51      0.29      0.14      1137
#
# -----------------------------------------------------------
# ...
